# %% [markdown]
# # Chinese Text Classification

# %%
# scripting language : Python 3.6
# modules : pandas, numpy, sklearn, bs4, jieba 

import time
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

import re
from bs4 import BeautifulSoup
import jieba
import jieba.analyse

# %% [markdown]
# ### Load data
#
# First, we load data into dataframe X_train, y_train X_text, and label encode the classes into [0,1,2].

# %%
# load data to dataframe
df_train = pd.read_csv("data/offsite-tagging-training-set.csv",  header=0)
df_test = pd.read_csv("data/offsite-tagging-test-set.csv",  header=0)
print("Load {} training examples and {} test cases".format(len(df_train), len(df_test)))

y_train = df_train['tags']
X_train = df_train['text']
X_test = df_test['text']

# label encode the classes
le = LabelEncoder()
y_train = le.fit_transform(y_train)

print("\nShow first training example: \n", X_train[0], "\n\nClass label:", y_train[0])
print("\nClass labels [0,1,2] refer to ",le.inverse_transform([0, 1, 2]))
# Out:
# Load 3894 training examples and 974 test cases
#
# Show first training example:
#  利物浦重賽擊敗乙組仔　英足盃過關 英格蘭足總盃第三圈今晨重賽，貴為英超勁旅的利物浦上場被乙組仔埃克斯特尷尬逼和，多獲一次機會的紅軍不敢再有差池。先有近期回勇的「威爾斯沙維」祖阿倫10分鐘開紀錄，加上兩個小將舒爾奧祖，及祖奧迪西拿下半場各入一球，以3比0擊敗對手，總算在主場挽 <p style="text-align: justify;">英格蘭足總盃第三圈今晨重賽，貴為英超勁旅的利物浦上場被乙組仔埃克斯特尷尬逼和，多獲一次機會的紅軍不敢再有差池。先有近期回勇的「威爾斯沙維」祖阿倫10分鐘開紀錄，加上兩個小將舒爾奧祖，及祖奧迪西拿下半場各入一球，以3比0擊敗對手，總算在主場挽回面子，下一圈對手為韋斯咸。</p> <p style="text-align: justify;">另一場英超球隊對壘，今季異軍突起的李斯特城戰至第三圈就宣告畢業。熱刺憑韓國前鋒孫興<U+615C>上半場遠射破網先開紀錄，換邊後此子助攻予中場查迪尼建功，令球隊以兩球輕取李斯特城，第四圈將面對英甲的高車士打。</p>
#
# Class label: 2
#
# Class labels [0,1,2] refer to  ['梁振英' '美國大選' '足球']

# %% [markdown]
# ### Text Preprocessing
#
# Next, we write two methods to build our own stopword dictionary and perform the following text cleaning procedures.
# * HTML tag removal using BeautifulSoup
# * Remove all english letters, numbers, symbols using regular expression
# * Perform chinese word segmentation using Jeiba
# * Remove stopwords using customised chinese stopwords and symbols
# * Join words with white space (for input to TfidfVectorizer in the next stage)

# %%
def build_stopwords(filepath):
    '''
    Load customized stopwords.txt
    Return a dictionary of stopwords
    '''
    with open(filepath,'r') as file:
        return set([line.strip() for line in file])

# %%
def clean_text(text_array):
    '''
    Remove html tags, symbols, letters a-z A-Z, numbers
    Perform chinese word segmentation
    Remove stopwords 
    Return list of cleaned text
    '''
    start_time = time.time() 
    print("--- Text Preprocessing ---")
    
    cleaned_text_array = []
    
    for i in range(len(text_array)):
        raw_text = text_array[i]
        cleaned_text = BeautifulSoup(raw_text, 'lxml').get_text()  
        chinese_only = re.sub("[0-9a-zA-Z\xa0\r\n\t\u3000\u2000-\u206F\u2E00-\u2E7F\!#$%&()*+,\-.\/:;<=>?@\[\]^_`{|}~]", "", cleaned_text)
        words = list(jieba.cut(chinese_only, cut_all=False))
        words = [word for word in words if str(word) not in stopwords]
        cleaned_text_array.append(" ".join(words))
        
    print("--- %s seconds --- \n" % (time.time() - start_time))
    
    return cleaned_text_array

# %%
# build dictionary of stopwords from customized stopwords file
stopwords = build_stopwords(filepath='stopwords.txt')

# text preprocessing
X_train_cleaned = clean_text(X_train)
X_test_cleaned = clean_text(X_test)

print("\nShow first training example in raw text: \n", X_train[0])
print("\nShow first training example after text preprocessing: \n", X_train_cleaned[0])
# Out:
# --- Text Preprocessing ---
# --- 52.093252182006836 seconds ---
#
# --- Text Preprocessing ---
# --- 13.8717360496521 seconds ---
#
#
# Show first training example in raw text:
#  利物浦重賽擊敗乙組仔　英足盃過關 英格蘭足總盃第三圈今晨重賽，貴為英超勁旅的利物浦上場被乙組仔埃克斯特尷尬逼和，多獲一次機會的紅軍不敢再有差池。先有近期回勇的「威爾斯沙維」祖阿倫10分鐘開紀錄，加上兩個小將舒爾奧祖，及祖奧迪西拿下半場各入一球，以3比0擊敗對手，總算在主場挽 <p style="text-align: justify;">英格蘭足總盃第三圈今晨重賽，貴為英超勁旅的利物浦上場被乙組仔埃克斯特尷尬逼和，多獲一次機會的紅軍不敢再有差池。先有近期回勇的「威爾斯沙維」祖阿倫10分鐘開紀錄，加上兩個小將舒爾奧祖，及祖奧迪西拿下半場各入一球，以3比0擊敗對手，總算在主場挽回面子，下一圈對手為韋斯咸。</p> <p style="text-align: justify;">另一場英超球隊對壘，今季異軍突起的李斯特城戰至第三圈就宣告畢業。熱刺憑韓國前鋒孫興<U+615C>上半場遠射破網先開紀錄，換邊後此子助攻予中場查迪尼建功，令球隊以兩球輕取李斯特城，第四圈將面對英甲的高車士打。</p>
#
# Show first training example after text preprocessing:
#  利物浦 重賽 擊敗 乙組 仔英足 盃 過關   英格蘭足 總 盃 第三圈 今晨 重賽 貴為 英超 勁 旅 利物浦 上場 乙 組仔 埃克斯 特 尷尬 逼 多獲 一次 機會的紅 軍 不敢 再有 差池 先有 近期 回勇 威爾斯沙維 祖阿倫 分鐘 開紀錄 加上 兩個 小將 舒爾奧祖 及祖奧 迪西 拿下 半場 各入 一球 以比擊敗 對 手 總算 主場 挽   英格蘭足 總 盃 第三圈 今晨 重賽 貴為 英超 勁 旅 利物浦 上場 乙 組仔 埃克斯 特 尷尬 逼 多獲 一次 機會的紅 軍 不敢 再有 差池 先有 近期 回勇 威爾斯沙維 祖阿倫 分鐘 開紀錄 加上 兩個 小將 舒爾奧祖 及祖奧 迪西 拿下 半場 各入 一球 以比擊敗 對 手 總算 主場 挽回 面子 下 一圈 對手 為 韋斯咸   另 一場 英超球 隊 對 壘 今季異 軍 突起 李斯特 城戰 至 第三圈 宣告 畢業 熱刺 憑 韓國 前鋒 孫興 上半 場遠射 破 網先 開紀錄 換邊 後 此子 助攻 予中場 查迪尼 建功 令球隊 兩球 輕取 李斯特 城 第 四圈 將面 對 英甲 高車士 打

# %% [markdown]
# ### Create Bag of Words
# We are now ready to create bag of words. We use TfidfVectorizer from sklearn to convert list of cleaned text into numeric representation. Basically, it counts word occurance frequency and normalizes it by putting more weight on rare and meaningful words. After tf-idf transformation, we have created a dictionary of size 1425. Each text is now represented as a feature vector of 1425 dimensions.
#
# Note that X_train_tfidf.shape = (3894, 1425). We use this for input of Randon Forest Classifer in the next stage.

# %%
# create Bag of Words using tf-idf transform
print("--- Create Bag of Words using TfidfVectorizer ---")

start_time = time.time() 
tfidf = TfidfVectorizer(tokenizer=lambda x: x.split(), lowercase=False, min_df=100) #minumum document frequency set to 100
X_train_tfidf = tfidf.fit_transform(X_train_cleaned)

print("--- %s seconds --- \n" % (time.time() - start_time))

print("Number of words in dictionary : {}".format(len(tfidf.get_feature_names())))
print("Show some words in dictionary : \n", tfidf.get_feature_names()[::100])
# Out:
# --- Create Bag of Words using TfidfVectorizer ---
# --- 1.5314240455627441 seconds ---
#
# Number of words in dictionary : 1421
# Show some words in dictionary :
#  ['一仗', '事', '傳球', '半場', '回合', '完成', '怎樣', '撕裂', '有些', '港元', '相比', '美國', '變得', '選戰', '風波']

# %% [markdown]
# ### Random Forest Classification
# Next, we fit the training set (X_train_tfidf, y_train) to random forest classifier. We search the best parameter set by using grid search on 10-fold cross-validation. The model is evaluated using accurany score.

# %%
# grid search for best paramter set of random forest classifier
print("--- Training Random Forest Classifier ---")

rf = RandomForestClassifier()
params = {"max_depth":[None, 10, 50],  #max depth of trees
          "n_estimators":[10, 100]  #no. of tress to ensemble
         } 

model = GridSearchCV(estimator=rf, param_grid=params, scoring='accuracy', cv=10, n_jobs=-1, verbose=0)
model.fit(X_train_tfidf, y_train)

print("\nThe best paramenter set is : \n", model.best_params_)
print("\nScores:")
for scores in model.grid_scores_:
    print(scores)
# Out:
# --- Training Random Forest Classifier ---
#
# The best paramenter set is :
#  {'max_depth': None, 'n_estimators': 100}
#
# Scores:
# mean: 0.99024, std: 0.00396, params: {'max_depth': None, 'n_estimators': 10}
# mean: 0.99230, std: 0.00381, params: {'max_depth': None, 'n_estimators': 100}
# mean: 0.98151, std: 0.00636, params: {'max_depth': 10, 'n_estimators': 10}
# mean: 0.99024, std: 0.00561, params: {'max_depth': 10, 'n_estimators': 100}
# mean: 0.98819, std: 0.00652, params: {'max_depth': 50, 'n_estimators': 10}
# mean: 0.99153, std: 0.00564, params: {'max_depth': 50, 'n_estimators': 100}
# /Users/sukilau/anaconda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)

# %% [markdown]
# ### Prediction on Test Set
#
# Finally, we make prediction on the test set using the best parameter model obtained by grid search.

# %%
# make prediction on test set
print("--- Making prediction on test set ---")

prediction = model.predict(tfidf.transform(X_test_cleaned))
prediction_le = le.inverse_transform(prediction)
solution = pd.DataFrame(prediction_le, df_test['id'], columns = ["tag"])
solution.to_csv("prediction.csv")

print("Prediction on all test cases saved in prediction.csv\n")

print("Show prediction on all test cases:")
for i in range(len(X_test)):
    print(prediction_le[i],":", X_test[i][0:20], "...")
# Out:
# --- Making prediction on test set ---
# Prediction on all test cases saved in prediction.csv
#
# Show prediction on all test cases:
# 足球 : 南華添鋒力　簽前厄瓜多爾國腳保耶 港超勁 ...
# 梁振英 : 如果大學$0捐款　科大嶺南將蝕過千萬元  ...
# 足球 : 英超最強火力對碰　雙城爭冠靠鋒霸 英超今 ...
# 足球 : 【01球評】膺半程冠軍　阿仙奴今季不奪標 ...
# 梁振英 : 【書商失蹤】梁振英：希望失蹤的李波本人提 ...
# 梁振英 : 【施政盤點】三份施政報告　僅一半政策達標 ...
# 梁振英 : 【施政盤點】「治港絕招」　設19委員會　 ...
# 足球 : 高普首簽　「新馬迪」來季投紅軍 利物浦傷 ...
# 足球 : 「最潮主帥」鬥利物浦：我已領先1：0 英 ...
# 足球 : 紅軍超殘陣逼和英乙隊　高普：負擔不起重賽 ...
# 足球 : 【施丹上馬】皇馬六條A　退下來各自精彩　 ...
# 足球 : 【施丹上馬】踢而優則教　碧根鮑華告魯夫完 ...
# 足球 : 【01球評】施丹首戰　回歸原點抄足肥安　 ...
# 足球 : 新兵白鶴對辦　東方大破南華踞榜首現霸氣  ...
# 足球 : 【意甲半程總結】四軍混戰　拿玻里勢破祖記 ...
# 足球 : 【01球評】協同效應+品牌角力　美斯C朗 ...
# 足球 : 金球獎合併5年　首屆美斯得獎爭議最大 自 ...
# 梁振英 : 梁振英批司法覆核遭濫用　對政府代價大 現 ...
# 梁振英 : 【港大民調】支持度僅37%創新低　數據顯 ...
# 梁振英 : 【獨家民調】梁治三年　市民最不滿政制司法 ...
# 美國大選 : 奧巴馬炮轟特朗普耍選戰手段　承認未能團結 ...
# 梁振英 : 【施政報告】預留20億元成立創科創投基金 ...
# 梁振英 : 由象徵式政策到象徵式施政報告 師父教落， ...
# 梁振英 : 【施政報告】工聯會考慮不支持梁振英　梁連 ...
# 梁振英 : 港美同日發表施政藍圖　梁振英奧巴馬4大看 ...
# 梁振英 : 【獨家民調】青年人拒撐梁　無學生支持梁振 ...
# 足球 : 港中戰球迷噓國歌　FIFA再罰香港足總7 ...
# 梁振英 : 【01拆局】曾俊華民望雖高　未獲左派認可 ...
# 足球 : 【港足日與夜】從日與夜開始　了解五個香港 ...
# 梁振英 : 【施政報告】梁振英：即使當年有普選我仍會 ...
# 足球 : 【雙紅會】利曼雙城恩怨交纏歷百載　如今同 ...
# 梁振英 : 【台灣大選】「三英」都是「689」　振英 ...
# 足球 : 維拉問題球逼和　李斯特城痛失兩分 即使升 ...
# 足球 : 【雙紅會】魔迷最期待的畫面　費格遜再次出 ...
# 足球 : 巴塞大炒畢爾包　美斯半場傷出 巴塞隆拿今 ...
# 足球 : 新帥古杜連好腳頭！　史雲斯一球挫屈福特  ...
# 梁振英 : 【套丁風雲】行會成員涉套丁　梁振英：會了 ...
# 美國大選 : 希拉里的政治形象學：從賢內助到女強人的風 ...
# 足球 : 摩連奴上海散心　合照簽名照單全收 不少主 ...
# 美國大選 : 保守派甜心　佩林撐特朗普代表共和黨選總統 ...
# 足球 : 施丹挑機射罰球近全中　C朗「騎膊馬」認輸 ...
# 梁振英 : 曾鈺成：泛民若守住立會否決權　下屆特首需 ...
# 足球 : 【港足日與夜：張煒琪（1）】茶餐廳的女足 ...
# 足球 : 【01球評】「蟹貨」賓迪基　請在禁區內耐 ...
# 足球 : 全德真普選　梅拿最受女球迷歡迎 「Jam ...
# 足球 : 華迪斯勢投標準列治　同鄉迪基亞送祝福 這 ...
# 足球 : 【阿車大戰】禾確特入廠10年　扶不起的阿 ...
# 足球 : 【阿車大戰】進攻哲學不停步　中場互換成必 ...
# 足球 : 歇冬後首捷　羅拔仔斥拜仁「睡<U+774 ...
# 足球 : 【01球評‧阿車大戰】伊雲洛域　失分之匙 ...
# 足球 : 給球迷熱血沸騰的一夜　拉爾拉拿補時建功　 ...
# 美國大選 : 《紐時》︰傳媒大亨彭博擬擲78億港元　部 ...
# 足球 : 大熱東方嚴寒中蟬聯銀牌　女主帥陳婉婷捧首 ...
# 足球 : 【阿車大戰】今季兩誘廠將被逐　雲格批哥斯 ...
# 美國大選 : 【美國大選】彭博擬選總統　桑德斯：富翁對 ...
# 足球 : 賣人鋪後路　皇馬阻奧斯爾投巴塞 到底皇家 ...
# 足球 : 傳已請辭　雲高爾今日定生死 曼聯換帥再有 ...
# 足球 : 巴塞門神今非昔比　華迪斯遭新隊友嫌棄 正 ...
# 足球 : 【01球評】10號仔亦要綠葉扶持　小球會 ...
# 足球 : 【西甲爭霸】癲佬正傳的內心戲　施蒙尼扮弱 ...
# 足球 : 尼馬欲與哥迪奧拿合作　即轉<U+8EDA ...
# 美國大選 : 希拉里22封電郵涉最高機密　美國政府禁止 ...
# 美國大選 : 【美國大選】同一戰場同一命運？希拉里浴火 ...
# 美國大選 : 【美國大選】桑德斯左傾吸票　舊瓶新酒政策 ...
# 美國大選 : 黨團會議 vs 初選 兩者大不同 美國黨 ...
# 足球 : 【泰利落車】泰利不獲續約　宣布季尾落車　 ...
# 足球 : 【01球評】泰利落車　誰最高興？ 林柏特 ...
# 美國大選 : 【美國大選】初選開鑼　白宮路上怒火滿途　 ...
# 足球 : 【泰利落車】再見！車路士球迷一生的隊長  ...
# 足球 : 文仙尼打<U+5421>舉中指　停賽一場 ...
# 足球 : 【哥帥入城】死對頭入主曼城　摩連奴拒認「 ...
# 足球 : 李斯特城贏紅軍續領風騷　阿仙奴失分跌落第 ...
# 足球 : 【小球隊大作戰】英聯賽分8級　沙福特城升 ...
# 梁振英 : 劉夢熊：去信特首是勸他不要做犯法事 曾是 ...
# 足球 : 巴塞7蛋贈華倫　加利佬拒請辭 魯營球場， ...
# 足球 : 【01球評】時間人物地點皆錯 　難為了加 ...
# 足球 : 【中超泡沫】江蘇天價截劫利物浦獵物　勢再 ...
# 足球 : 西維爾矮腳虎發威　勢晉西盃決賽撼巴塞 失 ...
# 足球 : 【中超泡沫】準江蘇新援泰斯拿　語言藝術更 ...
# 足球 : 【雙城奇謀】華迪Vs阿古路　大衛對哥利亞 ...
# 足球 : 【藍紅大戰】雲高爾：後上奪冠　其實唔難  ...
# 美國大選 : 【追蹤美大選】政綱好　不代表贏得到 桑德 ...
# 梁振英 : 香港政府臉書上拜年　CY最多人讚好　大< ...
# 美國大選 : 【美國大選】新罕布什爾州桑德斯扳一城　共 ...
# 美國大選 : 【美國大選】犯下後女權主義大忌　希拉里團 ...
# 美國大選 : 【美國大選】非主流動搖政壇　特朗普票源平 ...
# 足球 : 【英超爭霸】熱刺英格蘭青春班　不畏曼城  ...
# 梁振英 : 港大民研：施政報告滿意率淨值創回歸後新低 ...
# 足球 : 阿當莊臣涉兒童性罪行遭新特蘭解約 新特蘭 ...
# 足球 : 【阿李大戰】奧斯爾鬥李城前傳不續約　巴塞 ...
# 足球 : 利物浦6蛋贈維拉　得失球終達正數 近5場 ...
# 美國大選 : 【追蹤美大選】如何決定大法官繼任人　將左 ...
# 梁振英 : 八和會館新春團拜　阿姐︰9月演新劇 香港 ...
# 足球 : 【01球評】雲格拒放迪保治　曼聯因禍得福 ...
# 足球 : 【歐聯】PSG破軒迪克金身　雷斯嘆贏得少 ...
# 足球 : 火車頭球員「露底」　印普京肖象或被追罰  ...
# 足球 : 【有片】球王美斯創歷史　西甲入球破300 ...
# 足球 : 曼聯折迪基亞敗走丹麥　雲高爾：梅菲定律  ...
# 足球 : 【港足日與夜．黃梓浩2】手指不知所措地打 ...
# 足球 : 【港足日與夜．黃梓浩1】不想做Norma ...
# 美國大選 : 【拆局】教宗戳中特朗普死穴 　突顯美國「 ...
# 足球 : 曼迷喜訊　迪基亞無礙　周二足總盃後復出  ...
# 足球 : 水晶宮鬥熱刺　艾迪巴約首返白鹿徑　「一定 ...
# 足球 : 【車曼大戰】曼城半力出擊　1：5慘負車路 ...
# 足球 : 【英足盃】英甲護級隊Twitter推文拍 ...
# 梁振英 : 【預算案前瞻】前新聞統籌專員點評特首財爺 ...
# 足球 : 【有片】球證吹走過白界12碼　華倫青年軍 ...
# 足球 : 【歐聯預告】曼城出征基輔求反彈　柏帥：歐 ...
# 足球 : 前英格蘭領隊艾歷臣：中國足球前途無可限量 ...
# 梁振英 : 網民「嬲嬲」梁振英Facebook貼文　 ...
# 美國大選 : 【追蹤美大選】民主黨篇：兩個人　一樣有得 ...
# 梁振英 : 【關公災難】梁振英Fb頭像　半日吸六萬「 ...
# 足球 : 【聯賽盃決賽】拿斯尼染「曼城藍」　新髮色 ...
# 足球 : C朗責隊友未夠班　「球霸」形象水洗難清  ...
# 足球 : 【有片】基格納變身超級撒亞人　龜波氣功慶 ...
# 梁振英 : 馬嶽：梁振英口中「一小撮人」　有6萬人支 ...
# 梁振英 : 【書商受查】黎棟國：李波沒透露回內地方法 ...
# 美國大選 : 【超級星期二】桑德斯居下風盼奪4州　眾籌 ...
# 美國大選 : 【超級星期二】擔心特朗普當總統　共和黨人 ...
# 美國大選 : 【超級星期二】希拉里特朗普出線看漲　各奪 ...
# 美國大選 : 【追蹤美大選】特朗普　打破共和黨第十一誡 ...
# 足球 : 【北倫敦打<U+5421>】阿仙奴關鍵之 ...
# 足球 : 【德甲】多蒙特鬥拜仁變英雄內訌戰 塵世間 ...
# 美國大選 : 如特朗普出線　克魯茲魯比奧揚言支持　公然 ...
# 梁振英 : 【聚焦兩會】孫春蘭籲梁振英：構築愛國愛港 ...
# 美國大選 : 【美國大選】超級周末：反特朗普潮見效？　 ...
# 梁振英 : 張德江晤港區人大　座位安排看齊內地省市　 ...
# 美國大選 : 【初選拆局】克魯茲或後來居上　桑德斯弱點 ...
# 足球 : 【英超】紐卡素領隊麥卡倫　傳48小時內下 ...
# 足球 : 【有片】李斯特城主場入球　錄得0.3黎克 ...
# 足球 : 【英足總盃．球迷互動】阿仙奴晉8強損三將 ...
# 足球 : 【英足總盃‧互動圖表】車路士盃賽專剋愛華 ...
# 梁振英 : CY 叫白領跳落維港游水 據說中環白領  ...
# 足球 : 【01球評．歐霸】史高斯想念的不止費格遜 ...
# 美國大選 : 【特朗普效應】恐特朗普真跑出　網上掀「逃 ...
# 足球 : 【01球評．英超互動】教練生涯作賭注　賓 ...
# 足球 : 【英足總盃．有片】哥斯達又發作疑似咬巴利 ...
# 足球 : 【中甲戰報】貴州1：1梅州　「香港打<U ...
# 足球 : 【法甲王者】「巴黎先行」的PSG營銷術  ...
# 足球 : 【有片】澳洲狂牛衝入球場　足球小將飛奔逃 ...
# 足球 : 【世盃外圍賽】鄭智落選　或告別國足 踏入 ...
# 足球 : 【西甲趣聞】丹尼爾看透世事　「金錢徒添煩 ...
# 美國大選 : 新傷醫舊患：桑德斯和民主黨的選舉映畫戲  ...
# 美國大選 : 美大選再遇超級星期二　特朗普出線關鍵戰　 ...
# 美國大選 : 【美國大選】魯比奧退選　特朗普希拉里優勢 ...
# 足球 : 【英超爭霸】李斯特城如有神助　因有佛力加 ...
# 足球 : 【歐聯戰報】意甲全軍覆沒　英超保4個歐聯 ...
# 足球 : 【歐霸．曼聯Vs利物浦】雲高爾誓晉級：我 ...
# 梁振英 : 【01周報】拆局：民建聯卸下梁振英包袱　 ...
# 足球 : 羅勳奴大四喜　傑志6：1破東方晉聯賽盃決 ...
# 足球 : 【意甲傳奇】保方974分鐘不失球創歷史　 ...
# 足球 : 【英超爭霸．互動】曼聯小勝曼城　拉舒福特 ...
# 足球 : 【英超】7月北京上演曼市打<U+5421 ...
# 足球 : 【巨星殞落】荷蘭球王告魯夫肺癌病逝　終年 ...
# 足球 : 【足球政情】梁振英fb「貼波」讚港足雖敗 ...
# 足球 : 和富大埔陳平斥政府平日關顧不足：打場波就 ...
# 足球 : 【巨星殞落】舒尼達連向告魯夫致敬放錯相  ...
# 美國大選 : 【美國大選】特朗普場外大戰克魯茲　互嘲對 ...
# 足球 : 朴智星現身香港　看好李斯特城摘冠　盼曼聯 ...
# 美國大選 : 【美國大選】小鳥現身講台　桑德斯推與鳥同 ...
# 美國大選 : 美國MIT學者：貿易衝擊致失業重災區&n ...
# 梁振英 : 學童躲不過紅雨濕身上學　梁振英撐天文台以 ...
# 足球 : 【英超預告】烏普頓最後一夜　韋斯咸迎曼聯 ...
# 足球 : 【英超．圖輯】烏普頓公園的最後一晚　 U ...
# 足球 : 【歐國盃】瑞典公布最終名單　伊巴謙領6新 ...
# 足球 : 【球場暴力．有片】中國盃賽變擂台陣　江蘇 ...
# 足球 : 【英超】坎坷過後有艇搭？　諾域治巴桑11 ...
# 足球 : 【圖輯】波三痴踩場&mdash;&mda ...
# 足球 : 【再見忠臣】高路斯輕輕的走 　終結5年拉 ...
# 足球 : 【意甲】希古恩破66年入球紀錄　助拿玻里 ...
# 美國大選 : 特朗普女伴簡史：下屬也必須漂亮　畢業冊稱 ...
# 美國大選 : 【有片】珍妮花羅倫斯氣頂特朗普歧視女性　 ...
# 足球 : 【01球評．互動】Big 4已死　群雄並 ...
# 足球 : 【歐國盃】英格蘭26人初選名單　拉舒福特 ...
# 梁振英 : 【張德江訪港】口徑不統一？央視用「視察」 ...
# 梁振英 : 【張德江訪港】朱幼麟：封路擾民非張德江原 ...
# 梁振英 : 【港大民調】最熟悉政治人物：梁國雄攀升第 ...
# 梁振英 : 【張德江訪港】特首設家宴　官員齊到場　馬 ...
# 足球 : 【英超真煞科<U+30FB>有片】曼聯贏 ...
# 足球 : 【歐國盃】德國初選小豬膝傷仍上榜　路維信 ...
# 梁振英 : 【01觀點】勿把焦點錯放「欽點」　令張德 ...
# 梁振英 : 【張德江訪港】泛民當面告狀　指梁振英緊張 ...
# 梁振英 : 【張德江訪港】泛民中央破冰會　梁家傑：首 ...
# 足球 : 【德甲．有片】法蘭克福隊長護級戰前確診睾 ...
# 梁振英 : 傳立會議員下月深圳考察　劉慧卿：不發回鄉 ...
# 美國大選 : 反對邀請特朗普　研究員遭解僱　智庫：員工 ...
# 足球 : 【港超季後附加賽】南華遭兩倒戈將射死　不 ...
# 足球 : 【突發．英超】曼聯炒雲高爾　摩連奴勢入主 ...
# 足球 : 【早晨精讀】忌廉哥尖東最後一日　大肚護士 ...
# 足球 : 【英冠附加賽】迪亞美一箭定江山　侯城挫錫 ...
# 足球 : 【美洲盃】蘇亞雷斯<U+551E>三周　 ...
# 美國大選 : 美國國務院報告轟希拉里　私人電郵處理公務 ...
# 美國大選 : 再有黨員表態支持　特朗普料達提名門檻　穩 ...
# 足球 : 【英足總盃】8強重賽改單場淘汰　小球會利 ...
# 足球 : 【歐聯決賽】最強對最強　精讀四大必睇位由 ...
# 梁振英 : 李君豪獲委任中大校董　曾為CY站台被指「 ...
# 梁振英 : 港澳小組下月開會　 北京派員調研梁振英評 ...
# 足球 : 【摩連奴掌曼聯】終於入魔了！摩連奴舉衫簽 ...
# 梁振英 : 梁智鴻點評三屆特首　讚梁振英「有心」惟做 ...
# 足球 : 【歐聯決賽】吻下來　豁出去　卡拉斯高紅爆 ...
# 梁振英 : 無<U+7DAB>專訪引述梁振英稱未決定 ...
# 足球 : 【歐聯決賽】8萬人齊撐皇馬勝利巡遊　C朗 ...
# 梁振英 : 傳林鄭曾俊華有意選特首　梁振英失笑：我們 ...
# 梁振英 : 梁振英評分跌至36.2分　民望再創新低  ...
# 美國大選 : 揭特朗普與鄭家純羅康瑞反目舊帳　羅：特朗 ...
# 梁振英 : 假梁振英fb宣布選特首　大量網民「中伏」 ...
# 足球 : 【歐國盃．D組分析】西班牙爭三連霸　與技 ...
# 足球 : 【歐國盃．小球隊大作戰6】弱旅大改造　威 ...
# 梁振英 : 撐梁振英連任？　四叔：我係佢就唔做喇 「 ...
# 美國大選 : 據說華人習慣威嚴，所以熱愛特朗普，真的嗎 ...
# 梁振英 : 特首網誌　首次談單一公司上市 半新股中銀 ...
# 足球 : 【驚天逃稅案】美斯自稱無辜 ：「我照父親 ...
# 足球 : 【港足日與夜．許嘉樂】跳出Comfort ...
# 足球 : 【歐國盃．B組分析】英格蘭威爾斯兄弟幫內 ...
# 美國大選 : 【列根逝世12年】向特朗普說不　加州保守 ...
# 足球 : 【西甲．有片】小球會雷加利斯　創會88年 ...
# 美國大選 : 【美國大選】希拉里的「男人煩惱」　特朗普 ...
# 梁振英 : 「活字典」王坤論盡房策30年　不支持「唔 ...
# 梁振英 : 【01獨家】「梁振英連任」中策組機密民調 ...
# 梁振英 : 【鉛水風波】林鄭上月企硬　梁振英：令居民 ...
# 美國大選 : 【美國大選】美聯社：希拉里夠票成民主黨總 ...
# 梁振英 : 【中策組機密民調】前顧問劉兆佳：以往民調 ...
# 梁振英 : 【早晨精讀】「梁振英連任」民調曝光　何韻 ...
# 足球 : 【歐國盃．備戰】C朗猛虎出押　葡萄牙友賽 ...
# 美國大選 : 【美國大選】參選員沃倫表態撐希拉里　當副 ...
# 足球 : 【歐國盃】羅馬尼亞平民兵　誓死守法國求爆 ...
# 梁振英 : 中策組公帑做特首連任民調　被批無關施政　 ...
# 足球 : 【歐國盃．網球】傳小豬伊雲洛域最後一刻棄 ...
# 足球 : 【歐國盃．點將】皮耶哭了　世盃棄將變法國 ...
# 足球 : 【歐國盃】法國旗開得勝　基奧特：我們要感 ...
# 足球 : 【美洲盃】美斯復出連中三元　阿根廷贈巴拿 ...
# 梁振英 : 林鄭訪美午餐會致辭　華媒不滿旁聽變「不准 ...
# 足球 : 【歐國盃．A組賽果】瑞士一球小勝　10人 ...
# 足球 : 【歐國盃．B組賽果】英格蘭僅和難逃宿命　 ...
# 足球 : 【歐國盃】北愛決賽周首戰前夕　高球手麥伊 ...
# 足球 : 【歐國盃】意大利新男神　自信packag ...
# 足球 : 科索沃足球隊獨立以來首場勝仗　奏起球員歸 ...
# 足球 : 【歐國盃】俄國阿爾巴尼亞撞徽章　兩地雙頭 ...
# 足球 : 【歐國盃．E組賽果】意大利突擊犀利　兩球 ...
# 足球 : 【歐國盃．F組賽果】C朗十腳射門不果　葡 ...
# 足球 : 【歐國盃】C朗小學雞上身揶揄冰島「一事無 ...
# 美國大選 : 奧巴馬特朗普交火白熱化　公仇私怨始於5年 ...
# 足球 : 【歐國盃．深宵福利】法式黑白配　沙格拿身 ...
# 足球 : 【歐國盃】神射手華迪貶後備　英格蘭鬥威爾 ...
# 足球 : 泰迪即將掌巴西帥印　或無緣里約奧運領軍  ...
# 足球 : 【歐國盃】瑞士軍刀「生鏽」　入球王沙基利 ...
# 足球 : 【歐國盃】迪基亞走出桃色風波　零撲救破賓 ...
# 足球 : 【美洲盃】奧斯賓拿救極刑　哥倫比亞挫秘魯 ...
# 足球 : 【歐國盃．互動】罰抄天敵　今屆姓氏最長球 ...
# 足球 : 【歐國盃．深宵福利】愛爾蘭之光　羅比堅尼 ...
# 足球 : 【歐國盃．點將】魔獸不笨　智勇兼備的盧卡 ...
# 足球 : 【歐國盃．點將】瑞士新貴沙加場上閃耀　雲 ...
# 足球 : 【歐國盃．點將】一傳一射建功　昔日死神變 ...
# 足球 : 【歐國盃．C組】德國變陣小勝北愛　與波蘭 ...
# 足球 : 【歐國盃．球評】突破格仔框架　克羅地亞技 ...
# 足球 : 【歐國盃．點將】比列錫射破西班牙　從法甲 ...
# 足球 : 【國際挑戰盃】南華迎祖雲達斯　門票明日發 ...
# 梁振英 : 【政情】廉署立會選舉前夕拘長毛　泛民建制 ...
# 梁振英 : 【迷你倉奪命火】親入火場　黎文軒痛哭：不 ...
# 梁振英 : 民陣轟政府施政失誤　本港人權情況惡化 民 ...
# 足球 : 【歐國盃．今晚3場焦點】瑞士波蘭守出個未 ...
# 足球 : 【歐國盃】英格蘭國腳專心備戰鬥冰島　卡尼 ...
# 足球 : 【歐國盃16強】愛爾蘭鋒即是衛　泊大巴鬥 ...
# 足球 : 【歐國盃16強】威爾斯延續神話　烏龍球挫 ...
# 足球 : 【歐國盃16強】基沙文4分鐘入2球　法國 ...
# 梁振英 : 【來稿】致立法會議員公開信：莫墮政治圈套 ...
# 足球 : 【法甲】PSG賠1.9億　與11冠教練白 ...
# 足球 : 【歐國盃16強】意大利復仇成功　碎西班牙 ...
# 足球 : 【歐國盃16強】英格蘭出局　鶴臣引咎辭職 ...
# 足球 : 【歐國盃．球評】給出局後的三獅球迷：眼睛 ...
# 足球 : 【美斯退隊】阿根廷總統開口力挽　布市豎銅 ...
# 梁振英 : 【七一授勳】林鄭獲頒大紫荊　歷任政務司長 ...
# 足球 : 【01球評．英超】尋找簡東拿　曼聯終找到 ...
# 足球 : 【美斯退隊】朗拿度︰美斯拋棄了我們　望後 ...
# 梁振英 : 【七一遊行】政府回應：期望各界大局為重配 ...
# 足球 : 【歐國盃8強】12碼射足9輪　德國險勝意 ...
# 足球 : 【歐國盃．球評】意大利其實沒有輸　只是出 ...
# 美國大選 : 【借畫寄意？】Marvel惡搞特朗普變奸 ...
# 梁振英 : 批借世界盃外圍賽引起中港對立　梁振英：願 ...
# 足球 : 【歐國盃8強】冰島下半場「贏」法國　球迷 ...
# 足球 : 【歐國盃．點將】普巴找到方向　撞破了冰山 ...
# 梁振英 : 無視梁振英批評言論　領展再創上市新高 特 ...
# 梁振英 : 消息：京官深圳分晤林鄭財爺談特首戰　兩司 ...
# 梁振英 : 拒回應京官見林鄭財爺　梁振英對司局長工作 ...
# 梁振英 : 【施政匯報】9骨灰龕場選址獲區會支持　隻 ...
# 足球 : 【里約奧運．足球】阿根廷18人名單出爐　 ...
# 足球 : 「十二碼一係入一係唔入」　WE2017首 ...
# 足球 : 【歐國盃決賽】C朗傷出照贏　葡萄牙加時一 ...
# 足球 : 【歐國盃】法國預製冠軍巡遊巴士慘變笑料  ...
# 足球 : 【歐國盃】葡萄牙封王的幕後功臣　最應多謝 ...
# 足球 : 【歐國盃】C朗僅扭傷　料錯過8月9日超級 ...
# 足球 : 【轉會動態】柏利投山東魯能年袋1.4億　 ...
# 足球 : 【足球趣聞】些路迪歐聯外圍賽不敵業餘隊　 ...
# 梁振英 : 【答問大會】泛民議員集中追問UGL事件　 ...
# 梁振英 : 【答問大會】建制議員接連批評梁振英　謝偉 ...
# 梁振英 : 【答問大會】建制派應支持梁振英連任？　林 ...
# 足球 : 【轉會動態】艾拿戴斯勢教英格蘭　莫耶斯或 ...
# 梁振英 : 【答問大會】工聯會郭偉強丟梁振英競選政綱 ...
# 足球 : 【即日履新】 Nike Magista  ...
# 足球 : 【英超】干地豪言領車路士重返歐聯 歐國盃 ...
# 足球 : Pokemon GO熱潮捲全球　體壇也瘋 ...
# 梁振英 : 【尼斯恐襲】港府維持對法國黃色外警　入境 ...
# 足球 : 【足球趣聞．有片】拿尼化身少林足球　加盟 ...
# 足球 : 【轉會動態】傳馬列斯拒續約　觸發李斯特城 ...
# 足球 : 廣州富力來季踢港超　法治倒退變人治 足總 ...
# 足球 : 【東方危機】班主黎同光停贊助　東方大縮水 ...
# 美國大選 : 布殊麥凱恩等齊缺席　共和黨全國大會首日現 ...
# 足球 : 【英超】李斯特城熱身賽馬列斯披甲　雲尼亞 ...
# 美國大選 : 【美國大選】獲7成票正式成為候選人　特朗 ...
# 足球 : 【轉會動態】葛斯重返多蒙特　回巢3子故劍 ...
# 美國大選 : 前維珍尼亞州長凱恩成希拉里副手 《華爾街 ...
# 美國大選 : 特朗普搶選票　挑保守派副手　出言討好黑人 ...
# 足球 : 【英超】莫耶斯回歸英超投新特蘭　拆禮物日 ...
# 足球 : 【迷你倉奪命火】球圈義賣球衣　為殉職消防 ...
# 足球 : 馬體會狂熱分子（中）：那奇蹟的一天，我成 ...
# 足球 : 【趣聞】大師兄返<U+569F>？！　港 ...
# 足球 : Pokemon GO成禁令　摩帥嚴禁球員 ...
# 美國大選 : 【追蹤美大選】民主黨政綱支持大麻合法化　 ...
# 足球 : 兩中國球員投西甲格蘭納達　新帥蒙在鼓裏︰ ...
# 美國大選 : 【民主黨大會】奧巴馬確認接班人　「沒有人 ...
# 足球 : 【港超】南華新季組班幾完成　最多增兩本地 ...
# 梁振英 : 【拆局】曾俊華曾鈺成表態選特首　溝淡「反 ...
# 梁振英 : 【特首選戰】曾鈺成表態「入閘」　意在「A ...
# 足球 : 【南華鬥祖雲】南華力戰1：2負祖記　表現 ...
# 足球 : 【英超】伊巴首戰閃電倒掛建功　曼聯友賽大 ...
# 足球 : 【港超】足總批准富力參賽　放寬本地球員限 ...
# 美國大選 : 「希拉里是魔鬼」　特朗普指美國大選或遭操 ...
# 足球 : 【港超】羅港威再上山　獲張廣勇賞識重披南 ...
# 美國大選 : 特朗普否認團隊內部分裂　希拉里支持率卻領 ...
# 足球 : 【里約奧運．男足】巴西首戰打多個悶和南非 ...
# 梁振英 : 【社論】只是「ABC」不足夠　符合擔當特 ...
# 梁振英 : 林大輝批梁振英「青年反政府屬正常」說法不 ...
# 美國大選 : 不滿特朗普希拉里　美前特工獨立候選人身分 ...
# 足球 : 【里約奧運．足球】森巴兵許勝不許和　誓挫 ...
# 足球 : 【里約奧運．今明必睇】港乒爭入女團4強　 ...
# 足球 : 【英超開鑼】李斯特城不敵侯城　27年來首 ...
# 梁振英 : 梁振英：港人有必要維護國家主權 行政長官 ...
# 美國大選 : 【美國大選】共和黨再有多名高官倒戈　反特 ...
# 足球 : 【里約奧運．足球】尼馬15秒閃電建功　巴 ...
# 足球 : 【西超盃】阿達杜倫梅開二度　助巴塞派3蛋 ...
# 足球 : 【英超】曼聯輕取修咸頓　伊巴梅開二度︰誰 ...
# 美國大選 : 選情不利軟化立場？特朗普：公平人道處理千 ...
# 足球 : 【01球評】熱刺拿玻里看似出硬線晉歐聯1 ...
# 足球 : 【告別小豬】舒韋恩史迪加結合技術與鐵血　 ...
# 足球 : 【曼市打<U+5421>】曼城戰曼聯前傳 ...
# 梁振英 : 【博評．錢志健】梁振英救港方法之一：請直 ...
# 梁振英 : 《大公》指成報主席收公款在逃　《成報》頭 ...
# 足球 : 【01球評】電視轉播費帶動　大球會改朝換 ...
# 足球 : 【01球評】荷蘭負希臘主場5連敗　對得住 ...
# 足球 : 【足球】美斯復出即做救世主　阿根廷以寡敵 ...
# 足球 : 【足球】艾拿戴斯奮鬥史：由25年前街頭籌 ...
# 足球 : 【足球】38歲林柏特　賽前預祝職業生涯3 ...
# 足球 : 黑池短片向張子岱致敬　舊隊友讚控球出色  ...
# 美國大選 : 【美國大選】特朗普企硬遣返千萬移民　希拉 ...
# 足球 : 【港足日與夜．張子岱】一代球王只為勝利而 ...
# 足球 : 【德甲】 紀念抗癌球迷　達斯泰特主場易名 ...
# 梁振英 : 立會定局成梁振英連任關鍵？　鍾樹根：幾難 ...
# 梁振英 : 加拿大總理杜魯多訪港　先見李嘉誠後見特首 ...
# 梁振英 : 【多圖】香港特首 VS 加國總理　出身、 ...
# 梁振英 : 曾蔭權罕有受訪　拒評梁振英表現　視許仕仁 ...
# 梁振英 : 【專訪‧有片】曾鈺成談下任特首任務：政改 ...
# 足球 : 【曼市打<U+5421>】曼聯曼城3季轉 ...
# 足球 : 【足球趣聞】費倫巴治搞新意　落實與Hel ...
# 足球 : 【西甲】馬德里雙雄禁買令上訴失敗　最快2 ...
# 美國大選 : 涉對克林頓基金會捐款人「特事特辦」　希拉 ...
# 梁振英 : 【特首選戰】跑馬仔開戰　曾蔭權代唐營發功 ...
# 足球 : 奧巴美揚膺《FIFA17》最快小明　比利 ...
# 梁振英 : 梁振英：橫洲萬七公屋先建四千是「先易後難 ...
# 美國大選 : 【美國大選】特朗普最期待的畫面出現了　自 ...
# 足球 : 【歐霸】曼聯輪換無效喪師飛燕諾　歐洲賽作 ...
# 足球 : 【01球評】曼聯仍未建立圍攻模式　進攻不 ...
# 美國大選 : 【美國大選】希拉里病後重投競選活動　稱小 ...
# 美國大選 : 【美國大選】特朗普俄亥俄佛州領先　希拉里 ...
# 美國大選 : 【美國大選】米歇爾首為希拉里站台　爭取年 ...
# 梁振英 : 【橫洲爭議】朱凱<U+5EF8>等17位 ...
# 足球 : 【英超】熱刺慘勝新特蘭　卡尼或傷韌帶損攻 ...
# 梁振英 : 曾俊華回應執行橫洲細節：無開梁振英領導小 ...
# 美國大選 : 【美國大選】小特朗普諷難民為有毒Skit ...
# 梁振英 : 【橫洲爭議】梁振英曾俊華今罕齊晤傳媒　官 ...
# 梁振英 : 【橫洲記招】梁振英認拍板分期　張炳良鄉事 ...
# 梁振英 : 【橫洲】《蘋果》引文件：梁志祥倡減建公屋 ...
# 美國大選 : 【美媒看大選】蓋洛普：小企數目不斷萎縮　 ...
# 梁振英 : 【橫洲記招】預演特首選戰CY風騷　財爺捱 ...
# 梁振英 : 【讀懂橫洲記招4大重點】CY認拍板減規模 ...
# 梁振英 : 三司會叫three C meeting？ ...
# 美國大選 : 【美國大選】「另類右翼」崛起　凸眼青蛙如 ...
# 足球 : 【英超】阿仙奴三將鬥射術　卡索拉重演亨利 ...
# 足球 : 馬耳他聯賽超級金球　施丹轉身加通坑渠射入 ...
# 美國大選 : 特朗普侮辱女性惹反感　荷里活女星群起表態 ...
# 梁振英 : 曾俊華「用眼睇」回應陳啟宗挺CY連任　再 ...
# 美國大選 : 特朗普希拉里電視辯論　大戰前夕各出其謀  ...
# 美國大選 : 內塔尼亞胡晤兩黨候選人　特朗普承認耶路撒 ...
# 美國大選 : 【selfie世代】希拉里出場　點解個個 ...
# 梁振英 : 海洋垃圾佔領石澳泳灘　驚現兩個製冷劑氣罐 ...
# 美國大選 : 【美國大選辯論】鬥爆金句　特朗普：我脾氣 ...
# 美國大選 : 【美國大選辯論．博評】「中國威脅論」不受 ...
# 梁振英 : 港視再申電視牌　行會發還通訊局再評估　王 ...
# 美國大選 : 【美國大選】首場辯論收視破紀錄　8400 ...
# 美國大選 : 【美國大選辯論．博評】特朗普「先升後跌」 ...
# 足球 : 【歐聯】馬體會多跑8.5公里　完美戰術破 ...
# 梁振英 : 【蔡東豪專欄】如果梁振英是CEO不是特首 ...
# 美國大選 : 【社論】價值危機、制度缺陷盡現　從總統大 ...
# 美國大選 : 【美國大選】特朗普首場辯論失威　下一場盲 ...
# 足球 : 【港足日與夜．高美斯】戰亂成長的鬥士　「 ...
# 梁振英 : 馮煒光去信《經濟學人》反擊　稱梁振英非共 ...
# 美國大選 : 【有片】由辯論台鬥到出街　希拉里特朗普初 ...
# 美國大選 : 【美國大選】密函揭特朗普懷疑避稅18年　 ...
# 美國大選 : 特朗普避稅秘技曝光！　他曾說：我醒目，信 ...
# 足球 : 【英超】曼聯憾和史篤城　普巴漸上力　朗尼 ...
# 美國大選 : 【美國大選】特朗普被揭多年不交稅　黨友齊 ...
# 美國大選 : 希拉里<U+9AEA>型進化史　從嬉皮風 ...
# 足球 : 英格蘭看守領隊修夫基首點兵　朗尼仍入選　 ...
# 足球 : 傑志會長伍健回應收地起樓　「香港足球未來 ...
# 梁振英 : 【轉載】逼走傑志訓練中心，不如先檢討短租 ...
# 美國大選 : 【美國大選】特朗普基金會涉違法　紐約州勒 ...
# 美國大選 : 【美國大選】財技炮製巨額虧損避稅　特朗普 ...
# 美國大選 : 【搖擺州選情】拉丁裔離共和黨而去　佛羅里 ...
# 足球 : 【英超】傳傑斯取代莫耶斯　新特蘭未開齋求 ...
# 足球 : 【足球趣聞】意乙現職業聯賽首面綠牌　表揚 ...
# 足球 : 【中甲】天津舊帥盧森保高轟基藍馬一場三犯 ...
# 美國大選 : 【福布斯富豪榜】蓋茨連續23年蟬聯榜首　 ...
# 足球 : 【世盃外圍賽】迪比長坐冷板落選　荷蘭缺星 ...
# 美國大選 : 【美國大選】紅星發力撐選舉　里安納度愛瑪 ...
# 足球 : C AllStar On仔街場做球王　車 ...
# 美國大選 : 【追蹤美大選】彭斯在選2016副總統？他 ...
# 梁振英 : 梁愛詩談特首條件：需對中央及特區有承擔　 ...
# 梁振英 : 下屆特首新增兩門檻　矛頭直指梁振英曾俊華 ...
# 美國大選 : 【美國大選】颶風考驗競選策略　希拉里機關 ...
# 梁振英 : 劉鳴煒捐4億　卡羅琳醫學院復修醫學中心成 ...
# 梁振英 : 【來稿】梁特首選舉承諾未兌現　長期服務金 ...
# 美國大選 : 【01動畫】倒數30天　美國大選進入大直 ...
# 美國大選 : 【速評<U+30FB>有片】鬥挖陳年性醜 ...
# 美國大選 : 【棄帥保車】共和黨現況如「阿波羅13號」 ...
# 梁振英 : 港大民調：曾俊華民望創8年新高　梁振英續 ...
# 梁振英 : 之前准普選，如今反不准選委自由選？ 如果 ...
# 足球 : 【港足日與夜．施寶盛】由西洋菜街踢到歐洲 ...
# 足球 : 【英超】態度決定生死　野孩子夏薩特鬥李城 ...
# 梁振英 : 118施政報告　222財政預算案　梁振英 ...
# 足球 : 【意甲】拿玻里有意斟38歲杜奧巴或高路斯 ...
# 美國大選 : 【美國大選】侮辱女性舊帳被翻　黨高層紛割 ...
# 美國大選 : 共和黨票倉猶他州倒米　特朗普慌了　希拉里 ...
# 足球 : 【英超】C朗少年時兩赴阿仙奴試腳　無緣入 ...
# 梁振英 : 135萬窮人口　創09年來新高　講扶貧之 ...
# 足球 : 【英超】哥迪奧拿挑戰朗奴高文　昔日隊友今 ...
# 美國大選 : 美調查指近半年輕人沒退休儲蓄　能破局者可 ...
# 足球 : 【西甲】C朗賽前吞神秘藥丸　破入球荒助皇 ...
# 美國大選 : 共和黨總部遭投擲易燃物品　特朗普煽動仇恨 ...
# 梁振英 : 斥反對派炒作UGL事件兩年　馮煒光：是百 ...
# 足球 : 【意甲】國米麻煩隊長自傳再惹麻煩　激怒球 ...
# 美國大選 : 特朗普妻開腔護夫：下體論只是「男孩對話」 ...
# 梁振英 : 李源潮：梁振英帶領特區穩妥施政　土地、房 ...
# 美國大選 : 杜特爾特訪華衝擊美國「重返亞太」　奧巴馬 ...
# 梁振英 : 【宣誓風波】傳北京兩手準備　倘申禁令失敗 ...
# 美國大選 : &nbsp;【追蹤美大選】信不信由你　四 ...
# 美國大選 : 厄瓜多爾認切斷阿桑奇網絡：防干預美國大選 ...
# 足球 : 【歐聯】巴禾打排球領紅　美斯大三元領巴塞 ...
# 足球 : 【01球評】曼城吞4蛋悟出道理　哥帥要贏 ...
# 美國大選 : 【美國大選辯論】特朗普大談陰謀論：攻打摩 ...
# 美國大選 : 特朗普式英語　「Big League」與 ...
# 美國大選 : 【第四場辯論？】特朗普希拉里晚宴再過招　 ...
# 梁振英 : 新華社突報道：《成報》主席谷卓恒　涉非法 ...
# 梁振英 : 【社論】扶貧過多於功不值吹噓　特首候選人 ...
# 足球 : 【歐霸】尹佩斯建功奧脫福全場起立鼓掌　搶 ...
# 足球 : 【意甲】保方反對中資入主米蘭雙雄　怒斥球 ...
# 美國大選 : 【美國大選】中美關係政隨人改？中國見識「 ...
# 美國大選 : 又回到最初的起點　希拉里特朗普民望未變　 ...
# 美國大選 : 【有片】爆陰私成競選新常態　特朗普科水　 ...
# 美國大選 : 到底特朗普說了什麼　膽大如布蘭森也感害怕 ...
# 美國大選 : 【01百科】香港選舉在周日　為何美國大選 ...
# 足球 : 【意甲】18歲青訓一球挫祖記　蒙迪拿：「 ...
# 美國大選 : 【美國大選】兩黨均向大企業傾斜　「1%社 ...
# 美國大選 : 【01百科】點解總統選舉係四年一次？　配 ...
# 美國大選 : 美式分權制度未必是金科玉律　遴選最高法院 ...
# 美國大選 : 蘋果新手機需漲價一倍？特朗普保護主義不切 ...
# 美國大選 : 美初選激鬥暴露不民主陋弊　民主黨「超級代 ...
# 美國大選 : 特朗普炒作中國貿易「強姦論」　貿易毀就業 ...
# 美國大選 : 美知識型經濟城市崛起　 人口增多收入不升 ...
# 美國大選 : 華艦首泊金蘭灣　折射美國重返亞洲陷死胡同 ...
# 美國大選 : 提倡分離主義暴力對待白人　美國黑人民族主 ...
# 美國大選 : 仇恨陰謀成主軸 「克林頓強姦」T恤揭大選 ...
# 美國大選 : 美大選外交戰　普京成焦點　希拉里特朗普對 ...
# 美國大選 : 成功女人背後的另一個女人　米歇爾能否將希 ...
# 美國大選 : 建制精英反建制？金融改革考驗希拉里　自由 ...
# 梁振英 : 美國香港終審制度對比　陳文敏：香港更能保 ...
# 梁振英 : 【宣誓風波】新民主同盟擬入稟　司法覆核特 ...
# 美國大選 : 【數到三，懂大選】美國大選101開班　梁 ...
# 美國大選 : 【專訪有片】港版特朗普與希拉里？　卿姐叻 ...
# 足球 : 【英聯盃】史杜列治梅開二度　利物浦挫熱刺 ...
# 美國大選 : 小布殊國務卿鮑威爾再倒戈　宣布票投希拉里 ...
# 美國大選 : 【種族矛盾】持續撕裂的美國社會　種族對立 ...
# 梁振英 : 【有片．數到三懂大選】美國總統只有270 ...
# 美國大選 : 北約東歐擴軍制衡俄國　戰後最大規模 北約 ...
# 梁振英 : 【特首選戰】傳曾俊華將辭職參選？　梁振英 ...
# 梁振英 : 【特首選戰．拆局】ABC陣營憂胡官?票　 ...
# 美國大選 : 【白宮之路第三站】主宰結果的五分一　為何 ...
# 美國大選 : 希拉里首次和第一夫人米歇爾同台造勢　米歇 ...
# 梁振英 : 【特首選戰】陳永棋讚曾俊華能幹、胡國興正 ...
# 梁振英 : 梁振英撰文總結五大政績　強調「利得稅達1 ...
# 梁振英 : 【特首選戰．來稿】失建築測量界票倉　北京 ...
# 美國大選 : FBI被指數周前已握「電郵門」新證據　延 ...
# 足球 : 【法甲】巴神7仗入7球俘虜球迷心　尼斯大 ...
# 足球 : 【意甲】17歲AC「新保方」前途無限　成 ...
# 美國大選 : 特朗普的時尚文化意味　領呔、帽子和襟章  ...
# 足球 : 【足球】狄恩教南華　簽約一年半　最快11 ...
# 梁振英 : 民調：梁振英支持率反彈8%　政府民望跌至 ...
# 足球 : 【歐聯預告】巴塞後防天殘地缺　曼城欲爭首 ...
# 梁振英 : 【宣誓風波 &middot; 拆局】中央 ...
# 梁振英 : 【有片】釋法滅獨前夕　CY經民聯晚宴高唱 ...
# 足球 : 【歐聯】根度簡梅開二度為哥迪奧拿復仇　曼 ...
# 美國大選 : 成功預測近9屆美國大選  穆迪「水晶球」 ...
# 美國大選 : 特朗普「獻醜」講印度語拉票　印裔選民<U ...
# 美國大選 : 特朗普還是川普？希拉里還是希拉莉希拉蕊？ ...
# 美國大選 : 經濟學家徐家健：寧選特朗普　勿投希拉里的 ...
# 美國大選 : 奧巴馬開腔護希拉里　暗批FBI局長淆亂視 ...
# 足球 : 【港足日與夜．林嘉緯】征戰港隊12年見盡 ...
# 美國大選 : Garbage Pail Kids美國大 ...
# 足球 : 【東亞盃】港足對手大起底　最大敵人朝鮮實 ...
# 梁振英 : 【宣誓風波．博評】李柱銘：人大千萬不要上 ...
# 足球 : 【足球】英業餘球隊斥10億建木製新球場　 ...
# 美國大選 : 賈慶國：特朗普現象反映美政治生態變化　非 ...
# 美國大選 : 希拉里白宮夢舉步維艱　突顯理念與行動的矛 ...
# 美國大選 : 希拉里背負「最惹人討厭」惡名　都怪克林頓 ...
# 梁振英 : 【樓市新辣招】住宅物業印花稅增至15%　 ...
# 梁振英 : 加辣記者會被追問淡化釋法　梁振英避答　僅 ...
# 美國大選 : 美國例外不例外？希拉里特朗普異曲同工 民 ...
# 美國大選 : 美國例外主義有宗教根源　稱謂源自共產主義 ...
# 美國大選 : 【拆局】特朗普須贏七搖擺州　希拉里誓守六 ...
# 梁振英 : 釋法前推樓市新辣招　住宅物業印花稅增至1 ...
# 美國大選 : 如果可以投票　美國學童投給&hellip ...
# 美國大選 : 【有片】「大俠」奧巴馬憤怒了　制止群眾欺 ...
# 美國大選 : 由墨西哥城到北京　美國今大選　舉世都在看 ...
# 美國大選 : 哈里王子緋聞女友談美大選　Meghan︰ ...
# 足球 : 【01球評】利物浦無堅不破　唯快不破 高 ...
# 梁振英 : 【選委戰】陳方安生弟「父子檔」上陣　7名 ...
# 美國大選 : 特朗普當選機會難排除　投資者58億賭墨西 ...
# 美國大選 : 特朗普或希拉里當總統　不同行業股份命運大 ...
# 美國大選 : 社科院專家袁征：特朗普已打開美國社會撕裂 ...
# 美國大選 : 質疑FBI調查不公　特朗普︰無人可8日查 ...
# 美國大選 : 今天投票　調查指希拉里90%當選　特朗普 ...
# 足球 : 【西甲】C朗續約皇家馬德里至2021年　 ...
# 美國大選 : 【從fashion 看大選】米歇爾奧巴馬 ...
# 美國大選 : 【美國大選】選戰第一槍！希拉里拔頭籌 　 ...
# 梁振英 : 【選委戰】汪明荃拖「梁粉」鄺美雲及高志森 ...
# 足球 : 【東亞盃】美女中場閃耀全場　韓國13球狂 ...
# 美國大選 : 社科院學者劉得手：美國對華焦慮含誇大誤判 ...
# 美國大選 : 當特朗普就任美國總統一百天　這個世界會變 ...
# 美國大選 : 美學者：美國民主步向衰亡　改革逼在眉睫　 ...
# 美國大選 : 高盛分析師：特朗普如當選　墨西哥披索料跌 ...
# 美國大選 : 選民渴望為國家選擇出路　票站排長龍　投票 ...
# 足球 : 【世盃外圍賽】山齊士拉傷小腿鬥曼聯成隱憂 ...
# 美國大選 : 【美國大選】選情緊湊　居港美國人：特朗普 ...
# 美國大選 : 【美國大選】勒邦占士最高調撐希拉里　美式 ...
# 美國大選 : 【特朗普當選】專家︰港股兩三日內回復平靜 ...
# 美國大選 : 【01觀點】首任女總統仍未誕生　美國女性 ...
# 美國大選 : 【有片】CNN黑人評論員心碎了：這是白人 ...
# 美國大選 : 特朗普勝選將成白宮新主人　網民對奧巴馬高 ...
# 美國大選 : 【特朗普當選】狂人總統收起傲氣　發表勝利 ...
# 美國大選 : 【特朗普當選】LadyGaga領銜示威　 ...
# 美國大選 : 【特朗普當選‧影片】李安頹住講白宮新主人 ...
# 美國大選 : 【特朗普當選】普京最開心？　美俄僵局料持 ...
# 梁振英 : 梁振英籲秉承孫中山遺志為國家發展努力　無 ...
# 美國大選 : 【特朗普當選．博評】勝選全靠Facebo ...
# 美國大選 : 【特朗普當選】極速消化狂人效應　歐美股市 ...
# 美國大選 : 狂人總統班底預測　金里奇做國務卿　朱利亞 ...
# 美國大選 : 哥大學者孫哲：特朗普面臨三大考驗　首務團 ...
# 美國大選 : 【博客非洲直擊】特朗普當選，遠隔重洋仍擔 ...
# 美國大選 : 【特朗普當選】 全球震驚？自由女神無眼睇 ...
# 美國大選 : 【特朗普當選】美多間大學發信慰問學生　將 ...
# 足球 : 【東亞盃】香港女足明鬥韓國　盼港人撐場（ ...
# 美國大選 : 特朗普黑天鵝原來在美債　投資者拋售令債息 ...
# 美國大選 : 【特朗普當選】新第一家庭人強馬壯顏值高　 ...
# 美國大選 : 朱克伯格發貼暗諷特朗普不按牌理　美學者： ...
# 美國大選 : 特朗普跟美國科企開戰？罵遍Apple、G ...
# 美國大選 : 無視民眾呼籲參選下屆總統　米歇爾坦言寧專 ...
# 美國大選 : 彼岸選出特朗普　歐洲右翼蠢蠢欲動　意大利 ...
# 美國大選 : 【特朗普當選】《Newsweek》回收1 ...
# 美國大選 : 【特朗普當選】New Balance高層 ...
# 美國大選 : 性別平權困難重重？LGBT同志、雙性戀及 ...
# 美國大選 : 希拉里仍有0.000000001%機會翻 ...
# 美國大選 : 特朗普當選　美防止自殺熱線來電倍增 CN ...
# 美國大選 : 特朗普「大轉<U+8EDA>」：願保留部 ...
# 足球 : 【世盃外】阿度里斯成西班牙最老入球者　意 ...
# 美國大選 : 【特朗普當選．博評】對不起，我們錯了 在 ...
# 足球 : 【世盃外】扯火迪斯高扯甩對手褲　累波斯尼 ...
# 美國大選 : 侮辱米歇爾「穿高跟鞋的猿人」帖文犯眾怒　 ...
# 足球 : 【足球】朗尼膝傷鬥西班牙倦勤　軒達臣頂上 ...
# 足球 : 【足球】林柏特離紐約城出路多　或回巢車路 ...
# 美國大選 : 為子女申請最高機密權限　特朗普一家玩轉美 ...
# 美國大選 : 桑德斯：民主黨應檢討失敗原因　繼續依賴捐 ...
# 足球 : 【足球】納比首戰和卡塔爾0：0　國足世盃 ...
# 美國大選 : 華爾街干政？傳億萬富豪、基金經理助陣　特 ...
# 美國大選 : 是時候收回選舉廢<U+564F>　耶倫才 ...
# 足球 : 【西甲】巴利誓破死穴　盼於馬德里打<U+ ...
# 梁振英 : 有消息指梁振英周一早上與習近平會面 正於 ...
# 梁振英 : 【特首選戰】習近平在利馬接見梁振英　並排 ...
# 美國大選 : 1998年就預測到特朗普會勝利？理查．羅 ...
# 足球 : 華朗返母會當主席　賣球會包廂達標　「找數 ...
# 美國大選 : 有其爺必有其孫？　特朗普祖父逃兵役遭德國 ...
# 美國大選 : 美大選過後社會仍分化　年輕人避出席感恩節 ...
# 足球 : 【足球】巴布亞新畿內亞女足世盃首入球　「 ...
# 足球 : 【謝拉特掛靴】要揀隊長　識揀一定揀謝拉特 ...
# 梁振英 : 張宇人否認入行會是政治酬勞或與梁連任有關 ...
# 美國大選 : 特朗普未定國務卿人選　羅姆尼忠誠成疑　朱 ...
# 足球 : 球壇性侵風波擴大　英警介入調查　克魯前管 ...
# 足球 : 英球圈醜聞擴大　逾20兒童疑曾遭性侵　有 ...
# 梁振英 : 為連任再提郊野公園建屋　梁振英低手又可笑 ...
# 梁振英 : 訪京見王光亞無談選特首　曾俊華：參選非個 ...
# 足球 : 中村狂熱份子（下）：夢想之行是怎樣煉成的 ...
# 梁振英 : 田北俊：梁特不連任「一天都光哂」　曾俊華 ...
# 梁振英 : 選委選舉反映，香港人心不死 12月11日 ...
# 足球 : 【英超】車路士10連勝干地仍發牢騷　利物 ...
# 足球 : 【哥倫比亞墜機】兩受傷球員回國治療　生還 ...
# 足球 : 【世冠盃】鹿島鹿角成亞洲之光　3戰全勝歷 ...
# 梁振英 : 無論是家變還是政變，還望中央對港轉走溫和 ...
# 足球 : 西甲第三勢力：一路走來西維爾 講起而家西 ...
# 美國大選 : 普京蔗渣價錢造出燒鵝味道　俄羅斯2016 ...
# 梁振英 : 新空管專家小組成員　一日走兩場咁忙？ 民 ...
# 梁振英 : 梁振英Facebook感謝政研會集會支持 ...
# 美國大選 : 每日3000電郵求轉<U+8EDA>不要 ...
# 梁振英 : 梁振英賀傅家俊逆轉勝：完美體現港人永不放 ...
# 梁振英 : Yahoo 2016熱搜名人論　游蕙禎「 ...
# 足球 : 【法甲】巴神梅開二度　尼斯拉開4分鎖定冬 ...
# 足球 : 【英超】利物浦補時絕殺愛華頓　軒達臣遭巴 ...
# 梁振英 : 曾俊華辭職未獲批　梁振英：唔想猜測中央想 ...
# 梁振英 : 【特首述職】拜訪發改委　梁振英：一帶一路 ...
# 足球 : 【足球】葡丙球隊否認踢茅波︰足球不是芭蕾 ...
# 梁振英 : 【特首述職】習近平：中央支持特區遏制港獨 ...
# 梁振英 : 西九文化區將設故宮文化博物館　梁振英、林 ...
# 足球 : 羅馬尼亞球隊特別版波衫披甲　白色Polo ...
# 足球 : 【2016體壇回顧．慘慘篇】這一年，「再 ...
# 梁振英 : 梁太批女兒病情差言論武斷　李慧<U+74 ...
# 足球 : 【哥倫比亞墜機】哥倫比亞公布初步調查　直 ...
# 足球 : 【球壇趣聞】五人足球傳奇法卡奧　扮露宿者 ...
# 足球 : 【英超】史雲斯領隊巴特利上任85日被炒　 ...
# 梁振英 : 【政圈風聲】商界料特首選戰打殘「取消MP ...
# 足球 : 盧旺達巫術厲害？　前鋒射極唔入　撕走咒符 ...
# 梁振英 : 2016年度政治潮語回顧　DQ、特事特辦 ...
# 美國大選 : 美國電力公司手提電腦驚現惡意程式　惟未必 ...
# 足球 : 【英超】利物浦新年破曼城　阿古路8戰晏菲 ...
# 足球 : 威爾斯勁旅27連勝破阿積士紀錄　教練︰難 ...
# 足球 : 【中超】雲格呼籲球星抵抗中超誘惑　「我一 ...
# 足球 : 【英超】哈利卡尼慶祝聯賽百場　兩射一傳率 ...
# 足球 : 卻奧斯藉<U+7740>新年抽水　朗拿度 ...
# 足球 : 【英超】曼聯13場不敗迎費格遜後最佳年代 ...
# 足球 : 【英超】雲格細數阿仙奴金球　「基奧特必入 ...
# 足球 : 【哥倫比亞墜機】查比高恩斯迎20名生力軍 ...
# 美國大選 : 特朗普就職典禮前夕　賴恩連任眾議院議長  ...
# 美國大選 : 世紀大和解？特朗普總統就職典禮　希拉里克 ...
# 梁振英 : 【特首選戰】梁振英搶咪講感受：為施政報告 ...
# 足球 : 【西班牙盃】九人巴塞隆拿淘汰馬體會　蘇亞 ...
# 足球 : 【亞冠外】泰維斯首戰夢遊　申花淪首資格賽 ...
# 梁振英 : 【特首選戰．博評】「我要真俊華」之惡 泛 ...
# 足球 : 【西甲】魯爾評皇馬史上5佳　捧C朗施丹拉 ...
# 足球 : 成功不靠父幹　奇連士文之子唔踢前鋒做門將 ...
# 足球 : 【英超】李斯特城5連敗勢危　雲尼亞里自責 ...
# 足球 : 【01球評】 李斯特城天堂變地獄　「破產 ...
# 足球 : 前利物浦浪人鋒將轉戰泰國　完美複製李華度 ...
# 足球 : 【亞冠盃】東方主場套票售罄　對恒大單場門 ...
# 足球 : 【英超．博評】雲格不走，阿仙奴只會永遠安 ...
# 足球 : 【歐霸】伊巴再做聖伊天殺手　曼聯5場不失 ...
# 足球 : 【英超】名哨卡頓保告別　難忘卡路爾鬼球與 ...
# 梁振英 : 梁粉羅康瑞提早續任貿發局主席　議員質疑梁 ...
# 足球 : 【亞冠盃‧曾錦濤曾至孝】前鋒拍檔到齊守防 ...
# 足球 : 【法甲】巴神離奇被逐　今季累積3紅冠絕五 ...
# 足球 : 【英足總盃】雙巴入替13分鐘反勝布力般　 ...
# 足球 : 越南球隊完場前被罰爭議12碼　積極不干預 ...
# 足球 : 【足球．博評】日本外流球星集體失勢 曾幾 ...
# 足球 : 【港超】前東方門將李溢晉藥檢肥佬　停賽2 ...
# 足球 : 【歐聯16強】基沙文成馬體會歐聯入球王　 ...
# 足球 : 【西甲】沙薩不窒步入金球　皇馬負華倫　榜 ...
# 梁振英 : 梁振英就UGL報道　再向《蘋果》發律師信 ...
# 梁振英 : 梁振英將增補為全國政協委員　陳永棋：文件 ...
# 足球 : 李斯特城極速炒領隊，打工仔有乜啟示？ 兩 ...
# 足球 : 雲邦荷斯古積特其利斷金　榜首飛燕諾盼18 ...
# 足球 : 【亞冠盃預告】東方三防中塞中路　迎川崎前 ...
# 梁振英 : 政協常委會通過增補為政協委員　梁振英：深 ...
# 足球 : 【蘇冠】拉夫流浪正副選門將全傷　中場臨時 ...
# 足球 : 【亞冠盃】東方多打兩人未竟全功　1：1賽 ...
# 足球 : 【利物浦】LFC World登陸香港　「 ...
# 梁振英 : 被指涉UGL不適合當政協副主席　梁振英： ...
# 足球 : 盤點有趣足球賭盤　咩都有得玩！ 瑟頓聯肥 ...
# 足球 : 【港超】辛祖林恩許破元朗主場3場不敗　傑 ...
# 足球 : 【英超】伊巴肘擊對手勢停賽3場　「佢跳起 ...
# 足球 : 【01球評】職場好人無好報　山齊士還有留 ...
# 梁振英 : 梁振英正式就UGL事件入稟告梁繼昌　開特 ...
# 足球 : 【英超】曼城悶和史篤城　主場首食白果　落 ...
# 足球 : 【英足總盃】法比「手術刀傳球」助攻率最高 ...
# 足球 : 【歐聯】球證拒評巴塞逆轉奇蹟　馬圖斯批亂 ...
# 足球 : 【足球】馬勒當拿赴上海搞青訓　盼中國隊有 ...
# 梁振英 : 【梁振英告誹謗．博評】特首告議員未嘗不可 ...
# 足球 : 【亞冠盃】李健和點評四徒弟 　葉鴻輝有一 ...
# 梁振英 : 【梁振英告誹謗．博評】告梁繼昌，特首問< ...
# 梁振英 : 【特首選舉．博評】選舉臨近，為何水靜鵝飛 ...
# 足球 : 【足球．博評】Football Mana ...
# 足球 : 【足球】秘魯門將真漢子　單場失22球自責 ...
# 足球 : 【歐聯抽籤】皇馬8強遇拜仁　巴塞重演15 ...
# 足球 : 【英超】李斯特城一洗342日之恥　挫韋斯 ...
# 足球 : 【U18青年賽】港隊一球負泰國　少國際賽 ...
# 足球 : 皇馬戰回歸盃告吹　利物浦落實7月中來港  ...
# 足球 : 【西甲】美斯梅開二度反勝華倫　巴塞主場連 ...
# 足球 : 【足球】基奧特開腔力撐雲格留任　「球隊大 ...
# 足球 : 【特首選舉．來稿】比「體育無經濟貢獻」更 ...
# 足球 : 【英超】曼聯官方證實：小豬將加盟芝加哥火 ...
# 足球 : 【德國Vs英格蘭】普多斯基奠勝　招牌重炮 ...
# 足球 : 【世盃外】巴利撩起火頭　高文恐怖斷腳　愛 ...
# 足球 : 【美職】小豬過體檢投芝加哥火燄　或踢十號 ...
# 足球 : 【世盃外】英格蘭Vs立陶宛　迪科爾老刀未 ...
# 梁振英 : 當選特首的第二天　林鄭與梁振英有甚麼不同 ...
# 足球 : 【世盃外】巴西明鬥巴拉圭　7歲小法格拿曬 ...
# 足球 : 【世盃外】美斯涉罵球證被FIFA調查　或 ...
# 足球 : 【國際友賽】18歲新保方成意大利最年輕正 ...
# 足球 : 【世界盃】2026決賽周新建議　亞洲區增 ...
# 足球 : 【德甲】手指變形頂硬上　「最佳射手」變最 ...
# 足球 : 【英超】李斯特城從5連敗到4連勝　新帥莎 ...
# 足球 : 【五人足球】歐偉倫世界盃入3球　香港曾經 ...
# 足球 : 誰販賣他們的足球夢：法國足球與非洲人口販 ...
# 足球 : 【中超】泰維斯投申花水土不服　傳有意提前 ...
# 足球 : 【港超】大埔半場演入球騷　菁英盃後再勝南 ...
# 足球 : 【西甲】巴塞爆冷負馬拉加　四大神奇數據　 ...
# 足球 : 【亞冠盃．鞠盈智】走出10個月膝傷低潮　 ...
# 足球 : 【歐聯】多蒙特球迷義務提供住宿　數十摩納 ...
# 足球 : 【歐聯】皇馬反勝拜仁　C朗破659分鐘入 ...
# 足球 : 【歐聯】多蒙特被襲翌日即補賽　失12碼兼 ...
# 足球 : 【亞冠】恒大失榜首大菲嬲嬲　保連奴涉非法 ...
# 足球 : 【英超】車路士再鬥曼聯誓保清白身　簡迪馬 ...
# 足球 : 【鬼佬愛港足<U+30FB>三】打氣惹投 ...
# 足球 : 【意甲】中資61億完成收購AC米蘭　貝盧 ...
# 足球 : 查比高恩斯奪意外後首冠　主帥：寫下球隊新 ...
# 足球 : 【英冠】白禮頓升班英超　時隔34年再戰頂 ...
# 足球 : 【英超】泰利車路士22年緣盡　季尾離隊未 ...
